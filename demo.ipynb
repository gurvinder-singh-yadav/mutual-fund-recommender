# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import datetime
import pandas as pd
import os
import json
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup

# %%
def get_stock_info(start, stop):
        
        driver = webdriver.Chrome(
        ChromeDriverManager().install(),
                )
        today = str(datetime.date.today())

        df = pd.read_csv("data/grow/{}/stocks_index.csv".format(today))
        urls = df["href"].iloc[start:stop].tolist()
        names = df["name"].iloc[start:stop].tolist()
        stock = {}
        for idx, (name, url) in enumerate(zip(names, urls)):
                root_dir = "data/grow/{}/stock".format(today)
                path = os.path.join(root_dir, "{}.json".format(idx + start))
                driver.get(url)
                try:
                        element = driver.find_element(By.XPATH, "//body/div[@id='__next']/div[@id='root']/div/div[@class='container web-align ']/div[@class='row pw14Container']/div[@class='pw14MainWrapper']/div[@class='pw14ContentWrapper']/div[@class='col l12']/div[@class='container web-align']/div[@class='col l12 stkP12BelowFoldDiv']/div[@class='col l12 stkP12BelowFoldInnerCont']/div[@class='col l12']/div[@class='col l12']/div[@class='col l12']/section/section/div[@class='onMount-appear-done onMount-enter-done']/div[1]")
                        stock["todaymin"] = element.get_attribute("aria-valuemin")
                        stock["todaymax"] =  element.get_attribute("aria-valuemax")
                        stock["todaynow"] = element.get_attribute("aria-valuenow")
                        element = driver.find_element(By.XPATH, "//body/div[@id='__next']/div[@id='root']/div/div[contains(@class,'container web-align')]/div[@class='row pw14Container']/div[@class='pw14MainWrapper']/div[@class='pw14ContentWrapper']/div[@class='col l12']/div[@class='container web-align']/div[@class='col l12 stkP12BelowFoldDiv']/div[@class='col l12 stkP12BelowFoldInnerCont']/div[@class='col l12']/div[@class='col l12']/div[@class='col l12']/section/section/div[@class='onMount-appear-done onMount-enter-done']/div[1]")
                        stock["52min"] = element.get_attribute("aria-valuemin")
                        stock["52max"] =  element.get_attribute("aria-valuemax")
                        stock["52now"] = element.get_attribute("aria-valuenow")
                        print(stock)
                        xpath = "//body/div[@id='__next']/div[@id='root']/div/div[contains(@class,'container web-align')]/div[@class='row pw14Container']/div[@class='pw14MainWrapper']/div[@class='pw14ContentWrapper']/div[@class='col l12']/div[@class='container web-align']/div[@class='col l12 stkP12BelowFoldDiv']/div[@class='col l12 stkP12BelowFoldInnerCont']/div[@class='col l12']/div[@class='col l12']/div[@class='col l12']/section/section/div[@class='onMount-appear-done onMount-enter-done']/div[1]"
                        change_price = driver.find_element(By.XPATH, "//div[@class='lpu38Day fs14 primaryClr']")
                        stock["price_change"] = change_price.text
                        div = driver.find_element(By.XPATH, xpath)
                        innerhtml = div.get_attribute("innerHTML")
                        soup = BeautifulSoup(innerhtml, "html.parser")
                        names = [i.text for i in soup.find_all("div", {"class" : "stpp34KeyText stpp34KeyTextStk fs14"})]
                        values = [i.text for i in soup.find_all("span", {"class": "stpp34Value fs16"})]
                        element = driver.find_element(By.XPATH, "//table[@class='tb10Table col l12 ft785Table']")
                        trs = element.find_elements(By.TAG_NAME, "tr")
                        for i in range(len(trs)):
                                tds = trs[i].find_elements(By.TAG_NAME, "td")
                                names.append(tds[0].text)
                                values.append(tds[1].text)
                        print(names)
                        print(values)
                        xpath =  "//div[@class='col l12 stkP12Section onMount-appear-done onMount-enter-done']//table[1]"
                        element = driver.find_element(By.XPATH, xpath)
                        trs = element.find_elements(By.TAG_NAME, "tr")
                        for i in range(len(trs)):
                                tds = trs[i].find_elements(By.TAG_NAME, "td")
                                names.append(tds[0].text)
                                values.append(tds[1].text)
                        xpath = "//div[@class='col l12 stkP12Section onMount-appear-done onMount-enter-done']//table[2]"
                        element = driver.find_element(By.XPATH, xpath)
                        print(names)
                        print(values)
                        trs = element.find_elements(By.TAG_NAME, "tr")
                        for i in range(len(trs)):
                                tds = trs[i].find_elements(By.TAG_NAME, "td")
                                if "Symbol" in tds[0].text:
                                        names.append("Symbol")
                                else:
                                        names.append(tds[0].text)
                                values.append(tds[1].text)
                        stock.update(dict(zip(names, values)))
                        print(stock)
                        
                        stock["name"] = name
                        # print(path)
                        print(path)
                        with open(path, 'w') as f:
                                json.dump(stock, f, indent=4)
                except:
                        continue
        driver.close()

# %%
get_stock_info(0, 1)
# Out:
# {'todaymin': None, 'todaymax': None, 'todaynow': None, '52min': None, '52max': None, '52now': None}

# %%
driver = webdriver.Chrome(
        ChromeDriverManager().install(),
                )

# %%
url = "https://groww.in/stocks/reliance-industries-ltd"
driver.get(url)

# %%
soup = BeautifulSoup(driver.page_source, "lxml")

# %%
soup
# Out:
# <html data-theme="light" lang="en"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/><link href="/favicon-32x32-groww.ico" rel="icon" sizes="32x32" type="image/png"/><title>Reliance Industries Share Price Today - Reliance Industries Ltd Stock Price Live NSE/BSE</title><meta content="Reliance Industries Share Price - Get Reliance Industries Ltd LIVE BSE/NSE stock price with Performance, Fundamentals, Market Cap, Share holding, financial report,
#     company profile, annual report, quarterly results, profit and loss" name="description"/><meta content="index" name="robots"/><meta content="summary_large_image" name="twitter:card"/><meta content="https://groww.in/logo-groww270.png" name="twitter:image"/><meta content="Reliance Industries Share Price - Get Reliance Industries Ltd LIVE BSE/NSE stock price with Performance, Fundamentals, Market Cap, Share holding, financial report,
#     company profile, annual report, quarterly results, profit and loss" name="twitter:description"/><meta content="Reliance Industries Share Price Today - Reliance Industries Ltd Stock Price Live NSE/BSE" name="twitter:title"/><meta content="_@groww" name="twitter:site"/><meta content="_@groww" name="twitter:creator"/><meta content="Reliance Industries Share Price Today - Reliance Industries Ltd Stock Price Live NSE/BSE" itemprop="name"/><meta content="Reliance Industries Share Price - Get Reliance Industries Ltd LIVE BSE/NSE stock price with Performance, Fundamentals, Market Cap, Share holding, financial report,
#     company profile, annual report, quarterly results, profit and loss" itemprop="description"/><meta content="https://groww.in/logo-groww270.png" itemprop="image"/><meta content="en_US" property="og:locale"/><meta content="website" property="og:type"/><meta content="Reliance Industries Share Price Today - Reliance Industries Ltd Stock Price Live NSE/BSE" property="og:title"/><meta content="https://groww.in/logo-groww270.png" property="og:image"/><meta content="Reliance Industries Share Price - Get Reliance Industries Ltd LIVE BSE/NSE stock price with Performance, Fundamentals, Market Cap, Share holding, financial report,
#     company profile, annual report, quarterly results, profit and loss" property="og:description"/><meta content="https://groww.in/stocks/reliance-industries-ltd" property="og:url"/><meta content="Groww" property="og:site_name"/><link href="https://plus.google.com/b/112795119140865328446/+GrowwIn?" rel="publisher"/><link href="https://groww.in/stocks/reliance-industries-ltd" rel="canonical"/><meta content="24" name="next-head-count"/><meta content="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" property="csp-nonce"/><meta content="default-src 'self'; object-src 'none'; block-all-mixed-content; script-src 'self' 'nonce-LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=' https://*.groww.in/ wss://*.groww.in/ wss://groww.in/ https://*.freshchat.com/ https://cdn.yellowmessenger.com https://cloud.yellow.ai https://*.webengage.com/ http://cdn.widgets.webengage.com/ https://connect.facebook.net/ https://*.razorpay.com/ https://d2yyd1h5u9mauk.cloudfront.net/integrations/web/v1/library/ https://storage.googleapis.com/ https://www.googletagmanager.com/ https://tagmanager.google.com https://www.google-analytics.com/ https://ssl.google-analytics.com https://stats.g.doubleclick.net/ https://googleads.g.doubleclick.net/ https://www.googleadservices.com/ https://*.google.com/ https://www.google.co.in/ https://fonts.googleapis.com/ https://www.youtube.com/ https://www.youtube.com/iframe_api https://www.youtube-nocookie.com/ https://*.ingest.sentry.io https://hv-camera-web-sg.s3-ap-southeast-1.amazonaws.com/ https://hv-central-config.s3.ap-south-1.amazonaws.com/ https://hypersnapweb.hyperverge.co/ https://microapps.onemoney.in/ https://*.customfit.ai/ https://webrd.onemoney.in/ https://*.quora.com/ https://unpkg.com/ https://cdnjs.cloudflare.com/ https://www.gstatic.com/; prefetch-src 'self' https://*.groww.in/ wss://*.groww.in/ wss://groww.in/ https://*.freshchat.com/ https://cdn.yellowmessenger.com https://cloud.yellow.ai https://*.webengage.com/ http://cdn.widgets.webengage.com/ https://connect.facebook.net/ https://*.razorpay.com/ https://d2yyd1h5u9mauk.cloudfront.net/integrations/web/v1/library/ https://storage.googleapis.com/ https://www.googletagmanager.com/ https://tagmanager.google.com https://www.google-analytics.com/ https://ssl.google-analytics.com https://stats.g.doubleclick.net/ https://googleads.g.doubleclick.net/ https://www.googleadservices.com/ https://*.google.com/ https://www.google.co.in/ https://fonts.googleapis.com/ https://www.youtube.com/ https://www.youtube.com/iframe_api https://www.youtube-nocookie.com/ https://*.ingest.sentry.io https://hv-camera-web-sg.s3-ap-southeast-1.amazonaws.com/ https://hv-central-config.s3.ap-south-1.amazonaws.com/ https://hypersnapweb.hyperverge.co/ https://microapps.onemoney.in/ https://*.quora.com/ https://*.customfit.ai/ https://webrd.onemoney.in/; img-src 'self' data: blob: https://groww.in/ https://*.groww.in/ https://img.youtube.com/ https://i.ytimg.com https://i3.ytimg.com https://s3.amazonaws.com/cdn.freshdesk.com/ https://viewlogo.s3.amazonaws.com/ https://wchat.freshchat.com/ https://cdn.yellowmessenger.com https://www.google-analytics.com/ https://*.googleapis.com/ https://*.googleusercontent.com/ https://www.google.com/ https://www.google-analytics.com https://www.google.com/ads/ga-audiences https://www.googletagmanager.com https://ssl.gstatic.com https://www.gstatic.com https://stats.g.doubleclick.net/r/ https://stats.g.doubleclick.net/r/collect https://www.google.co.in/ads/ga-audiences https://*.ingest.sentry.io https://hv-camera-web-sg.s3-ap-southeast-1.amazonaws.com/ https://hv-central-config.s3.ap-south-1.amazonaws.com/ https://hypersnapweb.hyperverge.co/ https://microapps.onemoney.in/ https://*.quora.com/ https://*.customfit.ai/ https://webrd.onemoney.in/; style-src 'self' https://*.groww.in/ 'unsafe-inline' https://accounts.google.com https://wchat.freshchat.com/ https://fonts.googleapis.com https://cdn.yellowmessenger.com; font-src 'self' https://*.groww.in/ data: https://cdn. ...
#   if (Promise && !Promise.allSettled) {
#   Promise.allSettled = function(promises) {
#     return Promise.all(promises.map(function(promise) {
#       return promise.then(function(value) {
#         return { state: 'fulfilled', value: value };
#       }).catch(function(reason) {
#         return { state: 'rejected', reason: reason };
#       });
#     }));
#   };
# }</script><link as="style" href="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/css/233e0b2e5a21963b.css" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" rel="preload"/><link data-n-g="" href="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/css/233e0b2e5a21963b.css" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" rel="stylesheet"/><link as="style" href="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/css/ef46db3751d8e999.css" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" rel="preload"/><link data-n-p="" href="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/css/ef46db3751d8e999.css" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" rel="stylesheet"/><link as="style" href="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/css/d54b61c89021ef22.css" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" rel="preload"/><link data-n-p="" href="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/css/d54b61c89021ef22.css" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" rel="stylesheet"/><link as="style" href="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/css/533da4c27bf024a7.css" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" rel="preload"/><link data-n-p="" href="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/css/533da4c27bf024a7.css" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" rel="stylesheet"/><noscript data-n-css="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w="></noscript><script defer="" nomodule="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js"></script><script defer="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/webpack-8938086420a428e4.js"></script><script defer="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/framework-3f4adea299755495.js"></script><script defer="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/main-56ca366cc3357b31.js"></script><script defer="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/pages/_app-664d178507db6763.js"></script><script defer="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/e648a18a-f6f413efaa4065ee.js"></script><script defer="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/65149-ce39fb5421b3d0b2.js"></script><script defer="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/81413-d66a55ed808bd492.js"></script><script defer="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/55296-71b6a633c988d050.js"></script><script defer="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/61840-1b6fcdd4c5444144.js"></script><script defer="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/95451-3069e2046e2fc31d.js"></script><script defer="" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=" src="//assets-netstorage.groww.in/web-asse ...
#           Reliance Industries share price is ₹2,377.05 as of 30 Apr ‘23.
#           </div></div></div></div></div><div class="cur-po faq567QuesBorder"><div class="valign-wrapper vspace-between"><h3 class="ac11Title fw400 faq567Ques fs16">What is the Market Cap of Reliance Industries?</h3><svg class="ac11Icon absolute-center ac11collapsibleClose" fill="currentColor" height="20" viewbox="0 0 24 24" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M7.41 8.59L12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></div><div class="ac11Hidden" style="height: 0px; display: grid; grid-template-columns: 100%;"><div><div class="faq567Ans fs16"><div>Market capitalization, short for market cap, is the market value of a publicly traded company's outstanding shares.
#            The market cap of Reliance Industries is ₹16,37,609 Cr as of 30 Apr ‘23.
#           </div></div></div></div></div><div class="cur-po faq567QuesBorder"><div class="valign-wrapper vspace-between"><h3 class="ac11Title fw400 faq567Ques fs16"> What is the PE and PB ratio of Reliance Industries?</h3><svg class="ac11Icon absolute-center ac11collapsibleClose" fill="currentColor" height="20" viewbox="0 0 24 24" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M7.41 8.59L12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></div><div class="ac11Hidden" style="height: 0px; display: grid; grid-template-columns: 100%;"><div><div class="faq567Ans fs16"><div>The PE and PB ratios of Reliance Industries is 24.55366 and 1.99428 as of 30 Apr ‘23</div></div></div></div></div><div class="cur-po faq567QuesBorder"><div class="valign-wrapper vspace-between"><h3 class="ac11Title fw400 faq567Ques fs16"> What is the 52 Week High and Low of Reliance Industries?</h3><svg class="ac11Icon absolute-center ac11collapsibleClose" fill="currentColor" height="20" viewbox="0 0 24 24" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M7.41 8.59L12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></div><div class="ac11Hidden" style="height: 0px; display: grid; grid-template-columns: 100%;"><div><div class="faq567Ans fs16"><div>The 52-week high/low is the highest and lowest price at which a Reliance Industries stock has traded during that given time period
#           (similar to 1 year) and is considered as a technical indicator. The 52 week high and low of Reliance Industries is ₹2,856.15 and
#           ₹2,180.00 as of 30 Apr ‘23
#           </div></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="pw14ActionWrapper"><div class="sob32StickyDiv onMount-appear-done onMount-enter-done" style="margin-top: 77px;"><div class="msc999MainDiv center-align undefined onMount-appear-done onMount-enter-done" style="width: 340px; height: auto;"><div class="lazyload-wrapper"><img alt="Looking to invest in Stocks?" class="" height="87" loading="lazy" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/media/default.b40891fd.svg" width="130"/></div><div class="msc999Heading">Looking to invest in Stocks?</div><div class="msc999Para">Create your demat account on Groww in 2 minutes</div><div class=""><div class="btn51Btn btn51RipplePrimary btn51Primary" style="width: 100%; height: 45px; font-size: 14px;"><div class="absolute-center btn51ParentDimension"><span class="absolute-center" style="padding: 0px 25px;"><span>LOGIN / REGISTER</span></span></div></div></div></div></div></div></div></div></div><div class="col l12"><div class="row"><div class="col l12 fw500 fm77Cover1"><div class="container web-align"><div class="col l12 fm77ProductsLinks"><div class="col l3"><a href="/#"><div class="valign-wrapper pos-rel" itemscope="" itemtype="http://schema.org/Brand" style="min-width: 150px; min-height: 79px;"><img alt="Groww Logo" class="" height="50" src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/media/logo-light-groww.d72ab2aa.svg" width="150"/></div></a><p class="fm77Line1">Vaishnavi Tech Park, 3rd Floor</p><p class="fm77Line2">Sarjapur Main Road, Bellandur</p><p class="fm77Line2">Bengaluru – 560103</p><div class="cur-po"><p class="fm77Line2 fm77ContactUs"><u>Contact Us</u></p></div><div class="valign-wrapper fm77SocialMediaLinks"><div class="fm77IconsMargin"><a class="col l12" href="https://www.facebook.com/growwapp" rel="nofollow noopener noreferrer" target="_blank"><div class="lazyload-wrapper"><div class="lazyload-placeholder" style="height: 30px;"></div></div></a></div><div class="fm77IconsMargin"><a class="col l12" href="https://twitter.com/_groww" rel="nofollow noopener noreferrer" target="_blank"><div class="lazyload-wrapper"><div class="lazyload-placeholder" style="height: 30px;"></div></div></a></div><div class="fm77IconsMargin"><a class="col l12" href="http://bit.ly/2rjkBHu" rel="nofollow noopener noreferrer" target="_blank"><div class="lazyload-wrapper"><div class="lazyload-placeholder" style="height: 30px;"></div></div></a></div><div class="fm77IconsMargin"><a class="col l12" href="https://www.instagram.com/groww_official/" rel="nofollow noopener noreferrer" target="_blank"><div class="lazyload-wrapper"><div class="lazyload-placeholder" style="height: 30px;"></div></div></a></div><div class="fm77IconsMargin"><a class="col l12" href="https://in.linkedin.com/company/groww.in" rel="nofollow noopener noreferrer" target="_blank"><div class="lazyload-wrapper"><div class="lazyload-placeholder" style="height: 30px;"></div></div></a></div><div class="fm77IconsMargin"><a class="col l12" href="http://t.me/GrowwHQ" rel="nofollow noopener noreferrer" target="_blank"><div class="lazyload-wrapper"><div class="lazyload-placeholder" style="height: 30px;"></div></div></a></div></div></div><div class="col l9"><div class="col l4 fm77GrowwTxt"><div class="col l12 fs18 fm77FooterHeading">PRODUCTS</div><a class="col l12 fm77FooterLink" href="/stocks" target="_self">Stocks</a><a class="col l12 fm77FooterLink" href="/futures-and-options" target="_self">Futures &amp; Options</a><a class="col l12 fm77FooterLink" href="/mutual-funds" target="_self">Mutual Funds</a><a class="col l12 fm77FooterLink" href="/us-stocks" target="_self">US Stocks</a><a class="col l12 fm77FooterLink" href="/loans/personal-loan" target="_self">Credit</a><a class="col l12 fm77FooterLink" href="/stocks/[company-search-id]" target="_self">Groww Pay <em>(Coming Soon)</em></a><a class="col l12 fm77FooterLink" hr ...
# <script async="" src="https://widgets.in.webengage.com/js/webengage-min-v-6.0.js" type="text/javascript"></script><script data-nscript="afterInteractive" id="_webengage_script_tag" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w="> var webengage;!function(w,e,b,n,g){function o(e,t){e[t[t.length-1]]=function(){r.__queue.push([t.join("."),
#           arguments])}}var i,s,r=w[b],z=" ",l="init options track screen onReady".split(z),a="feedback survey notification".split(z),c="options render clear abort".split(z),p="Open Close Submit Complete View Click".split(z),u="identify login logout setAttribute".split(z);if(!r||!r.__v){for(w[b]=r={__queue:[],__v:"6.0",user:{}},i=0;i < l.length;i++)o(r,[l[i]]);for(i=0;i < a.length;i++){for(r[a[i]]={},s=0;s < c.length;s++)o(r[a[i]],[a[i],c[s]]);for(s=0;s < p.length;s++)o(r[a[i]],[a[i],"on"+p[s]])}for(i=0;i < u.length;i++)o(r.user,["user",u[i]]);setTimeout(function(){var f=e.createElement("script"),d=e.getElementById("_webengage_script_tag");f.type="text/javascript",f.async=!0,f.src=("https:"==e.location.protocol?"https://widgets.in.webengage.com":"http://widgets.in.webengage.com")+"/js/webengage-min-v-6.0.js",d.parentNode.insertBefore(f,d)})}}(window,document,"webengage");
#           window.webengage.init("in~76aa392");
#           </script><script data-nscript="afterInteractive" nonce="LdCbeOCQ8M6H5zVQfcLUNdgEPxFwx7WzvKsACtPBP5w=">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=!0;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f)})(window,document,'script','dataLayer','GTM-T7VTWPR')</script><webengagedata><style type="text/css">#webklipper-publisher-widget-container, #webklipper-publisher-widget-container * {overflow:visible; -webkit-box-sizing: content-box; -moz-box-sizing: content-box;  box-sizing: content-box; margin: 0; padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;}</style><div id="webklipper-publisher-widget-container"><iframe frameborder="0" id="webengage-engagement-callback-frame" marginheight="0" marginwidth="0" name="webengage-engagement-callback-frame" style="position: absolute; background-color: transparent; bottom: 0px; right: 0px; border: none; overflow: hidden; visibility: hidden; display: none;" title="webengage-engagement-callback-frame"></iframe><iframe frameborder="0" id="_we_wk_data_store" marginheight="0" marginwidth="0" name="_we_wk_data_store" src="https://inz76aa392.in.webengage.co/storage-frame-1.13.htm?cdn=y&amp;cbf=webengage-engagement-callback-frame&amp;lc=in~76aa392" style="position: absolute; background-color: transparent; bottom: 0px; right: 0px; border: none; overflow: hidden; visibility: hidden; display: none;" title="_we_wk_data_store"></iframe><script async="" charset="UTF-8" src="https://c.in.webengage.com/upf.js?lp=https%3A%2F%2Fgroww.in%2Fstocks%2Freliance-industries-ltd&amp;rf=&amp;geo=y&amp;jsonp=_we_jsonp_global_cb_1682932179552" type="text/javascript"></script></div></webengagedata><next-route-announcer><p aria-live="assertive" id="__next-route-announcer__" role="alert" style="border: 0px; clip: rect(0px, 0px, 0px, 0px); height: 1px; margin: -1px; overflow: hidden; padding: 0px; position: absolute; width: 1px; white-space: nowrap; overflow-wrap: normal;"></p></next-route-announcer><script async="" defer="" src="https://resources.groww.in/web-assets/rc-p.js?v=21236041" type="application/javascript"></script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","941915096655815");fbq("track","AbsolutePageView");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=941915096655815&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","941915096655815");fbq("track","AbsolutePageView");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=941915096655815&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <svg aria-hidden="true" style="width: 0px; height: 0px; position: absolute; top: -100%; left: -100%;"><text id="__react_svg_text_measurement_id">'23</text></svg>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","941915096655815");fbq("track","AbsolutePageView");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=941915096655815&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/13754-fc743fd331b3f134.js"></script><script src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/6175-37587c669a37540f.js"></script><script src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/81493-52cfa711d511c57a.js"></script><script src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/89549-727c3e1fadf583d2.js"></script><script src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/pages/options/%5BsearchId%5D-b81c0fc9d82f6e3f.js"></script><script src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/pages/index-00e63c58bc89d9da.js"></script><script src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/68758-147d36d3a8a73328.js"></script><script src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/13632-ed0cea733b5114ee.js"></script><script src="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/chunks/pages/stocks-5d43426a2bb46dcb.js"></script><script async="" defer="" src="https://accounts.google.com/gsi/client" type="text/javascript"></script></body></html>

# %%
driver.find_element(By.XPATH, "//div[@class='lpu38Day fs14 clrText']").text
# Out:
# '0.00 (0.00%) 1D'

# %%
driver.find_element(By.XPATH, "//body/div[@id='__next']/div[@id='root']/div/div[@class='container web-align ']/div[@class='row pw14Container']/div[@class='pw14MainWrapper']/div[@class='pw14ContentWrapper']/div[@class='col l12']/div[@class='container web-align']/div[@class='col l12 stkP12BelowFoldDiv']/div[@class='col l12 stkP12BelowFoldInnerCont']/div[@class='col l12']/div[@class='col l12']/div[@class='col l12']/section/section/div[@class='onMount-appear-done onMount-enter-done']/div[1]")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="be9dc5dd9405c6cc3b2ce6cb3ec084f2", element="f39d8352-6ce0-4f0e-b50a-562e2dd77473")>

# %%
element = driver.find_element(By.XPATH, "//body/div[@id='__next']/div[@id='root']/div/div[contains(@class,'container web-align')]/div[@class='row pw14Container']/div[@class='pw14MainWrapper']/div[@class='pw14ContentWrapper']/div[@class='col l12']/div[@class='container web-align']/div[@class='col l12 stkP12BelowFoldDiv']/div[@class='col l12 stkP12BelowFoldInnerCont']/div[@class='col l12']/div[@class='col l12']/div[@class='col l12']/section/section/div[@class='onMount-appear-done onMount-enter-done']/div[1]")

# %%
element.get_attribute("aria-valuemin")
