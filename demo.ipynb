# %%
import pandas as pd

# %%
df = pd.read_csv("data/news_processed.csv")

# %%
df[df["date"] == "2023-04-25"].head()
# Out:
#                                                 title  \
# 15  Buy IndusInd Bank, target price Rs 1450: Motil...
# 16  Buy IndusInd Bank, target price Rs 1375: JM Fi...
# 17  Buy Samvardhana Motherson International, targe...
# 18  Buy IndusInd Bank, target price Rs 1322: LKP S...
# 19  Buy Bank of Baroda, target price Rs 182.3 : IC...
#
#                                                  link  \
# 15  https://economictimes.indiatimes.com/markets/s...
# 16  https://economictimes.indiatimes.com/markets/s...
# 17  https://economictimes.indiatimes.com/markets/s...
# 18  https://economictimes.indiatimes.com/markets/s...
# 19  https://economictimes.indiatimes.com/markets/s...
#
#                                                  text  \
# 15  Promoters held 16.5 per cent stake in the comp...
# 16  IndusInd Bank, incorporated in the year 1994, ...
# 17  The brokerage reiterates BUY with Mar’24 TP of...
# 18  IndusInd Bank, incorporated in the year 1994, ...
# 19  Bank of Baroda, incorporated in the year 1911,...
#
#                            fund_name action  target  \
# 15  Motilal Oswal Financial Services    Buy  1450.0
# 16                      JM Financial    Buy  1375.0
# 17                      JM Financial    Buy   100.0
# 18                    LKP Securities    Buy  1322.0
# 19                      ICICI Direct    Buy     NaN
#
#                              stock_name        date
# 15                        IndusInd Bank  2023-04-25
# 16                        IndusInd Bank  2023-04-25
# 17  Samvardhana Motherson International  2023-04-25
# 18                        IndusInd Bank  2023-04-25
# 19                       Bank of Baroda  2023-04-25

# %%
df = df.fillna("No Info.")

# %%
df[df["date"] == "2023-04-25"].head()
# Out:
#                                                 title  \
# 15  Buy IndusInd Bank, target price Rs 1450: Motil...
# 16  Buy IndusInd Bank, target price Rs 1375: JM Fi...
# 17  Buy Samvardhana Motherson International, targe...
# 18  Buy IndusInd Bank, target price Rs 1322: LKP S...
# 19  Buy Bank of Baroda, target price Rs 182.3 : IC...
#
#                                                  link  \
# 15  https://economictimes.indiatimes.com/markets/s...
# 16  https://economictimes.indiatimes.com/markets/s...
# 17  https://economictimes.indiatimes.com/markets/s...
# 18  https://economictimes.indiatimes.com/markets/s...
# 19  https://economictimes.indiatimes.com/markets/s...
#
#                                                  text  \
# 15  Promoters held 16.5 per cent stake in the comp...
# 16  IndusInd Bank, incorporated in the year 1994, ...
# 17  The brokerage reiterates BUY with Mar’24 TP of...
# 18  IndusInd Bank, incorporated in the year 1994, ...
# 19  Bank of Baroda, incorporated in the year 1911,...
#
#                            fund_name action    target  \
# 15  Motilal Oswal Financial Services    Buy    1450.0
# 16                      JM Financial    Buy    1375.0
# 17                      JM Financial    Buy     100.0
# 18                    LKP Securities    Buy    1322.0
# 19                      ICICI Direct    Buy  No Info.
#
#                              stock_name        date
# 15                        IndusInd Bank  2023-04-25
# 16                        IndusInd Bank  2023-04-25
# 17  Samvardhana Motherson International  2023-04-25
# 18                        IndusInd Bank  2023-04-25
# 19                       Bank of Baroda  2023-04-25
